# %%
str(True) # string a sequence of characters defined in single, double or triple quotes are considered as string datatype.
# Out:
# 'True'

# %%
bool(" ")
# Out:
# True

# %%
str(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0bd3ca74295a> in <cell line: 1>()
# ----> 1 str(true)
#
# NameError: name 'true' is not defined

# %%
_x = 10

# %%
_x
# Out:
# 10

# %%
1x= 110
# Out:
#   File "<ipython-input-5-471341b36f6a>", line 1
#     1x= 110
#     ^
# SyntaxError: invalid decimal literal

# %%
name = "hare Krishna" # in python string indexing starts from 0 (it supports both positive and negative indexing).

# %%
name[0]
# Out:
# 'h'

# %%
name[3]
# Out:
# 'e'

# %%
"kdsj"[-1]
# Out:
# 'j'

# %%
name[7]
# Out:
# 'i'

# %%
name[-1]
# Out:
# 'a'

# %%
len(name)
# Out:
# 12

# %%
name[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-25aa37574f4e> in <cell line: 1>()
# ----> 1 name[12]
#
# IndexError: string index out of range

# %%
name[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-07f6e23d91c6> in <cell line: 1>()
# ----> 1 name[100]
#
# IndexError: string index out of range

# %%
name[11]
# Out:
# 'a'

# %%
name[-12]
# Out:
# 'h'

# %%
name[-13]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-8a8c28e275ed> in <cell line: 1>()
# ----> 1 name[-13]
#
# IndexError: string index out of range

# %%
name
# Out:
# 'hare Krishna'

# %%
# string methods
name.lower() # converts alphabets to lower case
# Out:
# 'hare krishna'

# %%
name.upper()
# Out:
# 'HARE KRISHNA'

# %%
name = "haRe KrisHna"

# %%
# convert all characters from lower to upper, upper to lower
name.swapcase()
# Out:
# 'HArE kRIShNA'

# %%
name.capitalize()
# Out:
# 'Hare krishna'

# %%
name1 = "Napolean7"

# %%
name1.isdigit()
# Out:
# False

# %%
name1.isnumeric() # TODo: check
# Out:
# False

# %%
name1.isalpha() # a string should have only alphabets
# Out:
# False

# %%
"krishna".isalpha()
# Out:
# True

# %%
name1.isalnum()
# Out:
# True

# %%
" ".isspace()
# Out:
# True

# %%
"a".isspace()
# Out:
# False

# %%
"c ".isspace()
# Out:
# False

# %%
# cases, boolean,
# Out:
# False

# %%
a = "madam"

# %%
a.count('a') # no.of occurances.
# Out:
# 2

# %%
a.count('m')
# Out:
# 2

# %%
a.count('z')
# Out:
# 0

# %%
a.find('c')
# Out:
# -1

# %%
a.find('m')
# Out:
# 0

# %%
"     ap ple    ".strip() # removes both leading and trailing spaces.
# Out:
# 'ap ple'

# %%
"     apple    ".lstrip()
# Out:
# 'apple    '

# %%
"     apple    ".rstrip()
# Out:
# '     apple'

# %%
"bat".zfill(5)
# Out:
# '00bat'

# %%
"bat".zfill(10)
# Out:
# '0000000bat'

# %%
"aeroplane".zfill(5)
# Out:
# 'aeroplane'

# %%
name = "Hare Krishna"

# %%
name.split()
# Out:
# ['Hare', 'Krishna']

# %%
name.split('e')
# Out:
# ['Har', ' Krishna']

# %%
name.split('a')
# Out:
# ['H', 're Krishn', '']

# %%
a, b, c = 1, 2, 3

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
name = "Hare Krishna"
name.split()
# Out:
# ['Hare', 'Krishna']

# %%
values = ['Hare', 'Krishna']

# %%
#output: HareKrishna
type(values)
# Out:
# list

# %%
''.join(values)
# Out:
# 'HareKrishna'

# %%
','.join(values)
# Out:
# 'Hare,Krishna'

# %%
":".join(values)
# Out:
# 'Hare:Krishna'

# %%
a_B_c = 1000

# %%
a_B_c
# Out:
# 1000

# %%
a, b = 10, 20

# %%
a, b, c = 1, 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-9dbc59cfd6c6> in <cell line: 1>()
# ----> 1 a, b, c = 1, 2
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
a = 10, 20, 30

# %%
a
# Out:
# (10, 20, 30)

# %%
type(a)
# Out:
# tuple

# %%
a = 1,00,000

# %%
a
# Out:
# (1, 0, 0)

# %%
x = 10_00_00_00_00_00_000

# %%
x
# Out:
# 100000000000000

# %%
10+20
# Out:
# 30

# %%
_
# Out:
# 30

# %%
_ = "shiv"

# %%
_
# Out:
# 'shiv'

# %%
# isdigit, isnumeric, isdecimal

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
str_int = "12345" # 0-9
arabic_int = "١٢٣٤٥"
dev_int = "१२३४५"

# %%
# all these functions will check all characters of a string should be digits
print(str_int.isdecimal()) # 0-9
print(str_int.isdigit()) # which accepts subscripts and super scripts
print(str_int.isnumeric()) # will check diff type number formats
# Out:
# True
# True
# True

# %%
print(arabic_int.isdigit())
print(arabic_int.isdecimal())
print(arabic_int.isnumeric())
# Out:
# True
# True
# True

# %%
dev_int.isnumeric()
# Out:
# True

# %%
"IV".isdigit()
# Out:
# False

# %%
"VI".isnumeric()
# Out:
# False

# %%
string1 = '123'
string2 = '⅓'
string3 = '²'

# %%
string3.isdigit()
# Out:
# True

# %%
print(string1.isnumeric())
print(string2.isnumeric())
print(string3.isnumeric())
# Out:
# True
# True
# True

# %%
'፫'.isdigit()
# Out:
# True

# %%
# replace all 'p' with the 'z'
"apple".replace('p', 'z')
# Out:
# 'azzle'

# %%
"apple".replace('p', 'z', 1)
# Out:
# 'azple'

# %%
"apple".replace('pp', 'b')
# Out:
# 'able'

# %%
"apple".replace('z', 'c')
# Out:
# 'apple'

# %%
fruit = "apple"

# %%
fruit[1]
# Out:
# 'p'

# %%
fruit[1] = 'c'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-0d8d24780fcd> in <cell line: 1>()
# ----> 1 fruit[1] = 'c'
#
# TypeError: 'str' object does not support item assignment

# %%
"8139834".isdigit()
# Out:
# True

# %%
x = """ ram
is
a
    good

boy
"""

# %%
print(x)
# Out:
#  ram
# is
# a
#     good
#
# boy

# %%
" ".isspace()
# Out:
# True

# %%
"                         ".isspace()
# Out:
# True

# %%
"".join(['a', 'b', 'c'])
# Out:
# 'abc'

# %%
x = "     apple    "

# %%
x.strip()
# Out:
# 'apple'

# %%
x.lstrip()
# Out:
# 'apple    '

# %%
x.rstrip()
# Out:
# '     apple'

# %%
"apple".zfill(10)
# Out:
# '00000apple'

# %%
a = 10

# %%
a = a+5

# %%
a
# Out:
# 15

# %%
a += 5
a
# Out:
# 20

# %%
"a" in "apple"
# Out:
# True

# %%
id(a)
# Out:
# 137462471443280

# %%
# address vs content
"apple" == "apple"
# Out:
# True

# %%
# is operator is used to check whether they same memory address or not
a = 10
b = 10

# %%
print(id(a), id(b))
# Out:
# 137462471442960 137462471442960

# %%
a is b
# Out:
# True

# %%
c = 20

# %%
id(c)
# Out:
# 137462471443280

# %%
a is c
# Out:
# False

# %%
a is not c # address should't be the same.
# Out:
# True

# %%
a is not b
# Out:
# False
