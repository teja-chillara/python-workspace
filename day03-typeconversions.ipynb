# %%
number:int = 90
decimal:float = 99.999
name:str = "Rama"
boolean:bool = True
com_val:complex = 5+8j

# %%
str_num = '89349'

# %%
int(str_num)
# Out:
# 89349

# %%
float(str_num)
# Out:
# 89349.0

# %%
int('839c')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-12695e6b58e9> in <cell line: 1>()
# ----> 1 int('839c')
#
# ValueError: invalid literal for int() with base 10: '839c'

# %%
# float

float(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-227ee7cc4c1f> in <cell line: 3>()
#       1 # float
#       2
# ----> 3 float(name)
#
# ValueError: could not convert string to float: 'Rama'

# %%
float(False)
# Out:
# 0.0

# %%
int(False)
# Out:
# 0

# %%
float(True)
# Out:
# 1.0

# %%
float(com_val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-75a3418675f4> in <cell line: 1>()
# ----> 1 float(com_val)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
# string
str(True)
# Out:
# 'True'

# %%
str(com_val)
# Out:
# '(5+8j)'

# %%
# boolean
# pass anything except 0 or "" that case only it will false, in all other cases it will be True.

bool(1)
# Out:
# True

# %%
bool(0.1)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool(" ")
# Out:
# True

# %%
# complex
# complex(real, imag)
complex(90)
# Out:
# (90+0j)

# %%
complex(imag=9)
# Out:
# 9j

# %%
complex(8, 9)
# Out:
# (8+9j)

# %%
complex(0, 10)
# Out:
# 10j

# %%
complex(real=5, imag=15)
# Out:
# (5+15j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('9343')
# Out:
# (9343+0j)

# %%
number
# Out:
# 90

# %%
name
# Out:
# 'Rama'

# %% [markdown]
# # Naming conventions

# %% [markdown]
# variable
#
# name = "Raja"
# num = 10 (num - name of a variable, 10-value)

# %% [markdown]
# 1. it will accept only alphabets(lower,upper), digits, underscore(_)
# 2. 1st character in name, shouldn't a number
# 3. only allowed special character is _
#
# 4. we snake case while naming it.
# 5. you can't give reserved keyword list as a name to a variable.

# %%
age? = 19
# Out:
#   File "<ipython-input-31-e8ca6b7c611e>", line 1
#     age? = 19
#        ^
# SyntaxError: invalid syntax

# %%
age_ = 19

# %%
age_
# Out:
# 19

# %%
1age = 29
# Out:
#   File "<ipython-input-34-9fe4121b5260>", line 1
#     1age = 29
#     ^
# SyntaxError: invalid decimal literal

# %%
a1ge = 29
print(a1ge)
# Out:
# 29

# %%
name10 = "Shiv"
print(name10)
# Out:
# Shiv

# %%
_age = 29

# %%
_age
# Out:
# 29

# %%
a_g_e = 30

# %%
a_g_e
# Out:
# 30

# %%
number = '83943"
# Out:
#   File "<ipython-input-41-f06e200062ae>", line 1
#     number = '83943"
#              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
number = '83943"'

# %%
number = "3i93'93849"

# %%
def = 100
# Out:
#   File "<ipython-input-44-2056c5c97273>", line 1
#     def = 100
#         ^
# SyntaxError: invalid syntax

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
True = 100
# Out:
#   File "<ipython-input-48-9efed9116db8>", line 1
#     True = 100
#     ^
# SyntaxError: cannot assign to True

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
while = False
# Out:
#   File "<ipython-input-50-76ff02d6cef2>", line 1
#     while = False
#           ^
# SyntaxError: invalid syntax

# %%
name = "ShiVFreeLanceR"

# %%
name
# Out:
# 'ShiVFreeLanceR'

# %%
name.upper()
# Out:
# 'SHIVFREELANCER'

# %%
name.lower()
# Out:
# 'shivfreelancer'

# %%
name.capitalize()
# Out:
# 'Shivfreelancer'
