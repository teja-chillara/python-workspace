# %%
def greet(a = "Hello", b):
  return a + " " + b

greet(b = "Jack")
# Out:
#   File "<ipython-input-2-48a0b531da7e>", line 1
#     def greet(a = "Hello", b):
#                            ^
# SyntaxError: non-default argument follows default argument

# %%
def greet(b, a = "Hello"):
  return a + " " + b

greet(b = "Jack")
# Out:
# 'Hello Jack'

# %%
a = [10]
print(a, type(a))
# Out:
# [10] <class 'list'>

# %%
a = (10)
print(a, type(a)) # 10, int
# Out:
# 10 <class 'int'>

# %%
a = (10,)
print(a, type(a)) # (10,), tuple
# Out:
# (10,) <class 'tuple'>

# %%
b = {1}
print(b, type(b))
# Out:
# {1} <class 'set'>

# %%
isinstance(True, int)
# Out:
# True

# %%
isinstance(False, int)
# Out:
# True

# %%
isinstance(True, bool)
# Out:
# True

# %%
isinstance(1, bool)
# Out:
# False

# %%
isinstance(1, (int, bool))
# Out:
# True

# %%
1 == True
# Out:
# True

# %%
# generic methods
1. print()
2. input()
3. len()
4. isinstance()
5. max()
6. min()
7. int(), float(), str(), complex(), bool()
8. list(), set(), frozenset(), tuple(), dict()
9. sum()
10. id()
# Out:
#   File "<ipython-input-14-d0e2a2ee4130>", line 2
#     1. print()
#        ^
# SyntaxError: invalid syntax

# %%
mutable ==> list, set, dict
immutable ==> tuple, frozenset

# %%
def test():
  return 10.99

# %%
test()
# Out:
# 10.99

# %%
def test():
  pass

print(test())
# Out:
# None

# %%
def test():
  return 1, 2, 3, 'str', True

test() # (1, 2, 3, 'str', True)
# Out:
# (1, 2, 3, 'str', True)

# %%
# **kwargs
# *args

# %%
def greet(a = "Hello",b = "Rohit"):
  return a + " " + b

greet()
# Out:
# 'Hello Rohit'

# %%
def details(Firstname, Lastname="Eswaran"):
  return "My name is " + Firstname + Lastname
details("Narmadha")
# Out:
# 'My name is NarmadhaEswaran'

# %%
def wish(a= "Happy birthday"):
  return f"{a} {name}"

name = input()
wish()
# Out:
# Rohit
# 'Happy birthday Rohit'

# %%
def subject(*args):
  print(type(args)) # tuple
  for arg in args:
    print(arg,type(arg)) # arg, str

subject('English','Maths','Social')
# Out:
# <class 'tuple'>
# English <class 'str'>
# Maths <class 'str'>
# Social <class 'str'>

# %%
def add(*args):
  print(args)
  return a-b
a = int(input())
b = int(input())
add()
# Out:
# 10
# 20
# ()
# -10

# %%
20

# %%
# OOPS
# 1. class
# 2. object
# 3. inheritance
# 4. encapsulation
# 5. polymorphism
# 6. Abstraction.

# %%
# class - blueprint - UML Diagram

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Person: # class, name of the class Person

  def __init__(self, name, phoneNumber, emailAddress) -> None: # constructor
    self.name = name
    self.phoneNumber = phoneNumber
    self.emailAddress = emailAddress

  def purchaseParkingPass(self): # method
    a = 10
    b = 20
    c = 30
    print(f'i am getting parking ticket cost is {c}')

# %%
p = Person(name="Revanth", phoneNumber = 34034039, emailAddress='test@gmail.com') # object
print(id(p))
p.purchaseParkingPass()

print(p.name)
print(p.emailAddress)
print(p.phoneNumber)
# Out:
# 137048477761008
# i am getting parking ticket cost is 30
# Revanth
# test@gmail.com
# 34034039

# %%
class Car:
  def __init__(self, brand):
    self.brand = brand
