# %%
s1 = frozenset() # immutable, duplicates are not allowed, no insertion order, no indexing.

# %%
type(s1)
# Out:
# frozenset

# %%
s1.add(12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a45d89b43f1c> in <cell line: 1>()
# ----> 1 s1.add(12)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
s2 = frozenset([1,2,3,4,1,2,3,4])
s2
# Out:
# frozenset({1, 2, 3, 4})

# %%
s3 = frozenset((1,2,3,4,1,2,3,4))
s3
# Out:
# frozenset({1, 2, 3, 4})

# %%
s4 = frozenset({1,2,3,4,1,2,3,4})
s4
# Out:
# frozenset({1, 2, 3, 4})

# %%
s3
# Out:
# frozenset({1, 2, 3, 4})

# %%
s3.union(s4)
# Out:
# frozenset({1, 2, 3, 4})
