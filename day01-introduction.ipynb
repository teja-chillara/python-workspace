# %%
a = 10
b = 20

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print(384937)
# Out:
# 384937

# %%
print(893493.93948)
# Out:
# 893493.93948

# %%
print(783834, 'riit')
# Out:
# 783834 riit

# %%
# Datatypes

# 1. integer  ==> int  2389248
# 2. Decimal ==>  float 3843.349
# 3. character  ==> str (single, double, triple)
# 4. boolean ===> bool (True, Flase)
# 5. complex  ==> complex (a+bi)

# %%
a = 10
b = 99.99
name = 'Sri Hari'
isMarried = False
isGf = False
isMajor = True

# %%
type(a)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
type(isGf)
# Out:
# bool

# %%
type(ismajor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3d3aef592b52> in <cell line: 1>()
# ----> 1 type(ismajor)
#
# NameError: name 'ismajor' is not defined

# %%
type(isMajor)
# Out:
# bool

# %%
# datatypes:
name = "Revanth"
age = 26
salary = 70290.93
address = "Chittoor"
isGraduate = True

# %%
type(age)
# Out:
# int

# %%
type(address)
# Out:
# str

# %%
type(isgraduate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b40c08002ce0> in <cell line: 1>()
# ----> 1 type(isgraduate)
#
# NameError: name 'isgraduate' is not defined

# %%
# complex: a+bi (math); i = sqrt(-1)
# python: a+bj a= real, b = imag
x = 10+20j

# %%
y = '3+2i'

# %%
type(y)
# Out:
# str

# %%
type(x)
# Out:
# complex

# %%
x.real
# Out:
# 10.0

# %%
x.imag
# Out:
# 20.0

# %%
x
# Out:
# (10+20j)

# %%
name1 = 'Revanth'
name2 = 'Sri Hari'

# %%
name1
# Out:
# 'Revanth'

# %%
name = input()
# Out:
# 576t8y

# %%
name
# Out:
# '576t8y'

# %%
name = input("please enter your name: ")
# Out:
# please enter your name: Hari

# %%
name
# Out:
# 'Hari'

# %%
age = input('enter your age')

type(age)
# Out:
# enter your age30
# str

# %%
print(age, type(age))
# Out:
# 30 <class 'str'>

# %%
# type converstions
# int()
age = int(age)

# %%
type(age)
# Out:
# int

# %%
salary
# Out:
# 70290.93

# %%
str(salary)
# Out:
# '70290.93'

# %%
int(salary)
# Out:
# 70290

# %%
int(99.99)
# Out:
# 99

# %%
x = True

# %%
# integer repr of boole True -1 , false - 0
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int('apple')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-145babf1bb04> in <cell line: 1>()
# ----> 1 int('apple')
#
# ValueError: invalid literal for int() with base 10: 'apple'

# %%
int('10000')
# Out:
# 10000

# %%
int('8349#')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-49c156108585> in <cell line: 1>()
# ----> 1 int('8349#')
#
# ValueError: invalid literal for int() with base 10: '8349#'

# %%
# float = float() # assignment

# %%
# bool = bool()

# %%
# complex = complex()

# %%
# string = str()

x: int = 10
y: float = 19.99
z: bool = False
w: complex = 10+20j

# %%
str(x)
# Out:
# '10'

# %%
str(y)
# Out:
# '19.99'

# %%
str(z)
# Out:
# 'False'

# %%
str(w)
# Out:
# '(10+20j)'

# %%
# ininstance

# isinstance(z, int)
isinstance(y, str)
# Out:
# False

# %%
type(y)
# Out:
# float

# %%
isinstance(w, int)
# Out:
# False
