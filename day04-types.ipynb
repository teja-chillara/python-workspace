# %% [markdown]
# 5 fundamental data types:
#
# 1. int
# 2. float
# 3. string
# 4. boolean
# 5. complex
#
# Convert from one datatype to another datatype
#
# ex: int -> float; boolean -> int

# %% [markdown]
# type conversion functions:
#
# 1. int(value): value the one which needs to converted to int
# 2. float(value)
# 3. string(value)
# 4. bool(value)
# 5. complex(value)

# %%
decimal = 34.98
flag = True
string_val = 'Siddhu'
int_val = 100
complex_val = 10+30j #a+ib

# %%
print('hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-8df0164c4e34> in <cell line: 1>()
# ----> 1 print('hello')
#
# TypeError: 'bool' object is not callable

# %%
print = True

# %%
print
# Out:
# True

# %%
print('world!!')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-ed16c32fd156> in <cell line: 1>()
# ----> 1 print('world!!')
#
# TypeError: 'bool' object is not callable

# %%
decimal:float = 34.98
flag: bool = True
string_val:str = 'Siddhu'
int_val:int = 100
complex_val: complex = 10+30j #a+ib

# %%
int_val = True

# %%
type(int_val)
# Out:
# bool

# %%
int_val = 100

# %%
# int(value) --> convert the value to integer
int(decimal)
# Out:
# 34

# %%
int(flag)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(string_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-3c4ff174870c> in <cell line: 1>()
# ----> 1 int(string_val)
#
# ValueError: invalid literal for int() with base 10: 'Siddhu'

# %%
int('19003940') # you should have only digits, but if you have a characters then you get ValueError
# Out:
# 19003940

# %%
int(int_val)
# Out:
# 100

# %%
int(complex_val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-758b324c9f66> in <cell line: 1>()
# ----> 1 int(complex_val)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
float(100)
# Out:
# 100.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
# string
str(True)
# Out:
# 'True'

# %%
# bool
bool(9)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(-9)
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
complex(9, 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-f4b6149e12a0> in <cell line: 1>()
# ----> 1 complex(9, 10)
#
# TypeError: 'complex' object is not callable
